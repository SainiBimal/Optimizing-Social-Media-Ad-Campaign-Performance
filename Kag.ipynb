# %% [markdown]
# # **Project Name**    - **Optimizing Social Media Ad Campaign Performance for Audience Engagement and ROI**

# %% [markdown]
# # **Data Wrangling**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the files
kag = pd.read_csv("/content/drive/MyDrive/Kag /KAG.csv")

# %%
kag
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# 0            7350       1    1.430000                 2                    1
# 1           17861       2    1.820000                 2                    0
# 2             693       0    0.000000                 1                    0
# 3            4259       1    1.250000                 1                    0
# 4            4133       1    1.290000                 1                    1
# ...           ...     ...         ...               ...                  ...
# 1138      1129773     252  358.189997                13                    2
# 1139       637549     120  173.880003                 3                    0
# 1140       151531      28   40.289999                 2                    0
# 1141       790253     135  198.710001                 8                    2
# 1142       513161     114  165.609999                 5                    2
#
# [1143 rows x 11 columns]

# %%
kag.isnull().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
# Change the datatypes
kag.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
# Checking For Duplicates
kag.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Feature Engineering

kag["Age_Gender"] = kag["age"].astype(str) + "_" + kag["gender"].astype(str)

# %%
kag.isnull().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# Age_Gender             0
# dtype: int64

# %%
kag.nunique()
# Out:
# ad_id                  1143
# xyz_campaign_id           3
# fb_campaign_id          691
# age                       4
# gender                    2
# interest                 40
# Impressions            1130
# Clicks                  183
# Spent                   869
# Total_Conversion         32
# Approved_Conversion      16
# Age_Gender                8
# dtype: int64

# %%
kag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                1143 non-null   int64
#  1   xyz_campaign_id      1143 non-null   int64
#  2   fb_campaign_id       1143 non-null   int64
#  3   age                  1143 non-null   object
#  4   gender               1143 non-null   object
#  5   interest             1143 non-null   int64
#  6   Impressions          1143 non-null   int64
#  7   Clicks               1143 non-null   int64
#  8   Spent                1143 non-null   float64
#  9   Total_Conversion     1143 non-null   int64
#  10  Approved_Conversion  1143 non-null   int64
#  11  Age_Gender           1143 non-null   object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 107.3+ KB

# %%
kag.describe()
# Out:
#               ad_id  xyz_campaign_id  fb_campaign_id     interest  \
# count  1.143000e+03      1143.000000     1143.000000  1143.000000
# mean   9.872611e+05      1067.382327   133783.989501    32.766404
# std    1.939928e+05       121.629393    20500.308622    26.952131
# min    7.087460e+05       916.000000   103916.000000     2.000000
# 25%    7.776325e+05       936.000000   115716.000000    16.000000
# 50%    1.121185e+06      1178.000000   144549.000000    25.000000
# 75%    1.121804e+06      1178.000000   144657.500000    31.000000
# max    1.314415e+06      1178.000000   179982.000000   114.000000
#
#         Impressions       Clicks        Spent  Total_Conversion  \
# count  1.143000e+03  1143.000000  1143.000000       1143.000000
# mean   1.867321e+05    33.390201    51.360656          2.855643
# std    3.127622e+05    56.892438    86.908418          4.483593
# min    8.700000e+01     0.000000     0.000000          0.000000
# 25%    6.503500e+03     1.000000     1.480000          1.000000
# 50%    5.150900e+04     8.000000    12.370000          1.000000
# 75%    2.217690e+05    37.500000    60.025000          3.000000
# max    3.052003e+06   421.000000   639.949998         60.000000
#
#        Approved_Conversion
# count          1143.000000
# mean              0.944007
# std               1.737708
# min               0.000000
# 25%               0.000000
# 50%               1.000000
# 75%               1.000000
# max              21.000000

# %%
kag.shape
# Out:
# (1143, 12)

# %%
kag
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# 0            7350       1    1.430000                 2                    1
# 1           17861       2    1.820000                 2                    0
# 2             693       0    0.000000                 1                    0
# 3            4259       1    1.250000                 1                    0
# 4            4133       1    1.290000                 1                    1
# ...           ...     ...         ...               ...                  ...
# 1138      1129773     252  358.189997                13                    2
# 1139       637549     120  173.880003                 3                    0
# 1140       151531      28   40.289999                 2                    0
# 1141       790253     135  198.710001                 8                    2
# 1142       513161     114  165.609999                 5                    2
#
#      Age_Gender
# 0       30-34_M
# 1       30-34_M
# 2       30-34_M
# 3       30-34_M
# 4       30-34_M
# ...         ...
# 1138    45-49_F
# 1139    45-49_F
# 1140    45-49_F
# 1141    45-49_F
# 1142    45-49_F
#
# [1143 rows x 12 columns]

# %%
a1 = kag.groupby("interest")[["Clicks","Impressions"]].sum().reset_index()
a1["CTR"] = a1["Clicks"] / a1["Impressions"]
a1
# Out:
#     interest  Clicks  Impressions       CTR
# 0          2     311      1727646  0.000180
# 1          7     410      2612839  0.000157
# 2         10    3317     17989844  0.000184
# 3         15    1609     10745856  0.000150
# 4         16    5144     31809524  0.000162
# 5         18    1524      8646488  0.000176
# 6         19    1188      6083217  0.000195
# 7         20    1234      6899907  0.000179
# 8         21     512      2833321  0.000181
# 9         22     717      3965401  0.000181
# 10        23     375      1836368  0.000204
# 11        24     419      2256874  0.000186
# 12        25    1066      5251719  0.000203
# 13        26    1113      4868639  0.000229
# 14        27    3409     16352527  0.000208
# 15        28    2025     10959830  0.000185
# 16        29    3315     18768653  0.000177
# 17        30     389      2190783  0.000178
# 18        31     195      1075312  0.000181
# 19        32    1138      6455261  0.000176
# 20        36     128       922928  0.000139
# 21        63    1675      8365640  0.000200
# 22        64     989      5085460  0.000194
# 23        65     372      1737547  0.000214
# 24        66     138       893407  0.000154
# 25       100     395      2023690  0.000195
# 26       101     524      2960453  0.000177
# 27       102     150      1160953  0.000129
# 28       103     333      1921053  0.000173
# 29       104     265      1412110  0.000188
# 30       105     453      2656351  0.000171
# 31       106     332      1592431  0.000208
# 32       107     639      4482111  0.000143
# 33       108     402      2763404  0.000145
# 34       109     572      2980365  0.000192
# 35       110     365      2434719  0.000150
# 36       111     260      1490896  0.000174
# 37       112     339      2324572  0.000146
# 38       113     233      1830565  0.000127
# 39       114     191      1066164  0.000179

# %% [markdown]
# # **Data Visualization**

# %%
plt.figure(figsize=(7,5))
sns.histplot(kag["Spent"], bins=20, kde=True)
plt.title("Distribution of Ad Spend")
plt.show()

# %%
data1 = kag["Age_Gender"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(data1, labels = data1.index, autopct="%1.1f%%", startangle=90)
plt.title("Ad Distribution by Gender")
plt.show()

# %%
p5 = kag.groupby(["interest", "Age_Gender"])["Approved_Conversion"].sum().unstack(fill_value=0)
p5 = p5.loc[p5.sum(axis=1).sort_values(ascending=False).index]

ax = p5.plot(kind="bar", stacked=True, figsize=(22, 10))
for container in ax.containers:
    ax.bar_label(container, label_type="center", fontsize=8)

plt.title("Approved Conversion by Interest and Age_Gender")
plt.xlabel("Interest")
plt.ylabel("Approved Conversion")
plt.show()

# %%
plt.figure(figsize=(22,6))
sns.barplot( data = a1, x="interest", y="CTR")

plt.title("CTR by Audience Interest")
plt.xlabel("Audience Interest")
plt.ylabel("Click-Through Rate")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=kag, x="Impressions", y="Clicks", hue="Age_Gender")
plt.title("Impressions vs Clicks")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=kag, x="Spent", y="Approved_Conversion", hue="Age_Gender")
plt.title("Spent vs Conversion by Gender and Age")
plt.show()

# %%
plt.figure(figsize=(10,6))
corr = kag.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # **Tasks**

# %% [markdown]
# **1) Which social media platforms drive the highest conversion rates and lowest CPA?**

# %%
d1 = kag.groupby("xyz_campaign_id")[["Impressions","Clicks" ,"Spent","Approved_Conversion"]].sum().reset_index()
d1
# Out:
#    xyz_campaign_id  Impressions  Clicks         Spent  Approved_Conversion
# 0              916       482925     113    149.710001                   24
# 1              936      8128187    1984   2893.369999                  183
# 2             1178    204823716   36068  55662.149959                  872

# %%
d1["CTR"] = (d1["Clicks"] / d1["Impressions"])*100
d1["Conversion_Rate"] = np.where(d1["Clicks"] > 0, (d1["Approved_Conversion"] / d1["Clicks"])*100, 0)
d1["CPA"] = np.where(d1["Approved_Conversion"] > 0, d1["Spent"] / d1["Approved_Conversion"], 0)
d1 = d1.set_index("xyz_campaign_id")
d1
# Out:
#                  Impressions  Clicks         Spent  Approved_Conversion  \
# xyz_campaign_id
# 916                   482925     113    149.710001                   24
# 936                  8128187    1984   2893.369999                  183
# 1178               204823716   36068  55662.149959                  872
#
#                       CTR  Conversion_Rate        CPA
# xyz_campaign_id
# 916              0.023399        21.238938   6.237917
# 936              0.024409         9.223790  15.810765
# 1178             0.017609         2.417656  63.832741

# %%
print(d1["Conversion_Rate"].idxmax())
print(d1["CPA"].idxmin())
# Out:
# 916
# 916

# %%
d1[["CPA", "Conversion_Rate"]].plot(kind="bar",figsize=(10, 6))
plt.title("CPA & Conversion Rate by Campaign")
plt.xlabel("Campaign ID")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# **2) How do audience demographics (age, gender, location) influence campaign effectiveness?**

# %%
d2 = kag.groupby("Age_Gender")[["Impressions","Clicks" ,"Spent","Approved_Conversion"]].sum().reset_index()
d2
# Out:
#   Age_Gender  Impressions  Clicks         Spent  Approved_Conversion
# 0    30-34_F     31571576    5099   7611.479995                  195
# 1    30-34_M     36421443    4384   7640.919991                  299
# 2    35-39_F     21439505    4161   6061.349992                   95
# 3    35-39_M     20665139    2933   5051.080003                  112
# 4    40-44_F     23396175    5177   7396.579984                   93
# 5    40-44_M     16208132    2559   4193.149997                   77
# 6    45-49_F     38455591    9441  13433.209993                  112
# 7    45-49_M     25277267    4411   7317.460004                   96

# %%
d2["CTR"] = (d2["Clicks"] / d2["Impressions"])*100
d2["Conversion_Rate"] = np.where(d2["Clicks"] > 0, (d2["Approved_Conversion"] / d2["Clicks"])*100, 0)
d2["CPA"] = np.where(d2["Approved_Conversion"] > 0, d2["Spent"] / d2["Approved_Conversion"], 0)
d2 = d2.set_index("Age_Gender")
d2 = d2.sort_values(by = "CPA", ascending = False)
d2
# Out:
#             Impressions  Clicks         Spent  Approved_Conversion       CTR  \
# Age_Gender
# 45-49_F        38455591    9441  13433.209993                  112  0.024550
# 40-44_F        23396175    5177   7396.579984                   93  0.022128
# 45-49_M        25277267    4411   7317.460004                   96  0.017450
# 35-39_F        21439505    4161   6061.349992                   95  0.019408
# 40-44_M        16208132    2559   4193.149997                   77  0.015788
# 35-39_M        20665139    2933   5051.080003                  112  0.014193
# 30-34_F        31571576    5099   7611.479995                  195  0.016151
# 30-34_M        36421443    4384   7640.919991                  299  0.012037
#
#             Conversion_Rate         CPA
# Age_Gender
# 45-49_F            1.186315  119.939375
# 40-44_F            1.796407   79.533118
# 45-49_M            2.176377   76.223542
# 35-39_F            2.283105   63.803684
# 40-44_M            3.008988   54.456493
# 35-39_M            3.818616   45.098929
# 30-34_F            3.824279   39.033231
# 30-34_M            6.820255   25.554916

# %%
heatmap = d2.style.background_gradient(cmap="YlGnBu")
heatmap
# Out:
# <style type="text/css">
# #T_fb940_row0_col0, #T_fb940_row0_col1, #T_fb940_row0_col2, #T_fb940_row0_col4, #T_fb940_row0_col6, #T_fb940_row7_col3, #T_fb940_row7_col5 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_fb940_row0_col3, #T_fb940_row5_col3 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_fb940_row0_col5, #T_fb940_row4_col0, #T_fb940_row4_col1, #T_fb940_row4_col2, #T_fb940_row4_col3, #T_fb940_row7_col4, #T_fb940_row7_col6 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_fb940_row1_col0, #T_fb940_row4_col5 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# #T_fb940_row1_col1 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_fb940_row1_col2 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_fb940_row1_col3 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_fb940_row1_col4 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_fb940_row1_col5 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_fb940_row1_col6 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_fb940_row2_col0 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_fb940_row2_col1 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# #T_fb940_row2_col2 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_fb940_row2_col3 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_fb940_row2_col4 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_fb940_row2_col5, #T_fb940_row5_col4 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_fb940_row2_col6 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_fb940_row3_col0 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_fb940_row3_col1 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_fb940_row3_col2, #T_fb940_row5_col0 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_fb940_row3_col3 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_fb940_row3_col4 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_fb940_row3_col5 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_fb940_row3_col6 {
#   background-color: #71c8bd;
#   color: #000000;
# }
# #T_fb940_row4_col4 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_fb940_row4_col6 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_fb940_row5_col1 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_fb940_row5_col2 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_fb940_row5_col5, #T_fb940_row6_col5 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_fb940_row5_col6 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_fb940_row6_col0 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_fb940_row6_col1, #T_fb940_row6_col2 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_fb940_row6_col3 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_fb940_row6_col4 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_fb940_row6_col6 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_fb940_row7_col0 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_fb940_row7_col1 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_fb940_row7_col2 {
#   background-color: #80cebb;
#   color: #000000;
# }
# </style>
# <table id="T_fb940" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb940_level0_col0" class="col_heading level0 col0" >Impressions</th>
#       <th id="T_fb940_level0_col1" class="col_heading level0 col1" >Clicks</th>
#       <th id="T_fb940_level0_col2" class="col_heading level0 col2" >Spent</th>
#       <th id="T_fb940_level0_col3" class="col_heading level0 col3" >Approved_Conversion</th>
#       <th id="T_fb940_level0_col4" class="col_heading level0 col4" >CTR</th>
#       <th id="T_fb940_level0_col5" class="col_heading level0 col5" >Conversion_Rate</th>
#       <th id="T_fb940_level0_col6" class="col_heading level0 col6" >CPA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age_Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb940_level0_row0" class="row_heading level0 row0" >45-49_F</th>
#       <td id="T_fb940_row0_col0" class="data row0 col0" >38455591</td>
#       <td id="T_fb940_row0_col1" class="data row0 col1" >9441</td>
#       <td id="T_fb940_row0_col2" class="data row0 col2" >13433.209993</td>
#       <td id="T_fb940_row0_col3" class="data row0 col3" >112</td>
#       <td id="T_fb940_row0_col4" class="data row0 col4" >0.024550</td>
#       <td id="T_fb940_row0_col5" class="data row0 col5" >1.186315</td>
#       <td id="T_fb940_row0_col6" class="data row0 col6" >119.939375</td>
#     </tr>
#     <tr>
#       <th id="T_fb940_level0_row1" class="row_heading level0 row1" >40-44_F</th>
#       <td id="T_fb940_row1_col0" class="data row1 col0" >23396175</td>
#       <td id="T_fb940_row1_col1" class="data row1 col1" >5177</td>
#       <td id="T_fb940_row1_col2" class="data row1 col2" >7396.579984</td>
#       <td id="T_fb940_row1_col3" class="data row1 col3" >93</td>
#       <td id="T_fb940_row1_col4" class="data row1 col4" >0.022128</td>
#       <td id="T_fb940_row1_col5" class="data row1 col5" >1.796407</td>
#       <td id="T_fb940_row1_col6" class="data row1 col6" >79.533118</td>
#     </tr>
#     <tr>
#       <th id="T_fb940_level0_row2" class="row_heading level0 row2" >45-49_M</th>
#       <td id="T_fb940_row2_col0" class="data row2 col0" >25277267</td>
#       <td id="T_fb940_row2_col1" class="data row2 col1" >4411</td>
#       <td id="T_fb940_row2_col2" class="data row2 col2" >7317.460004</td>
#       <td id="T_fb940_row2_col3" class="data row2 col3" >96</td>
#       <td id="T_fb940_row2_col4" class="data row2 col4" >0.017450</td>
#       <td id="T_fb940_row2_col5" class="data row2 col5" >2.176377</td>
#       <td id="T_fb940_row2_col6" class="data row2 col6" >76.223542</td>
#     </tr>
#     <tr>
#       <th id="T_fb940_level0_row3" class="row_heading level0 row3" >35-39_F</th>
#       <td id="T_fb940_row3_col0" class="data row3 col0" >21439505</td>
#       <td id="T_fb940_row3_col1" class="data row3 col1" >4161</td>
#       <td id="T_fb940_row3_col2" class="data row3 col2" >6061.349992</td>
#       <td id="T_fb940_row3_col3" class="data row3 col3" >95</td>
#       <td id="T_fb940_row3_col4" class="data row3 col4" >0.019408</td>
#       <td id="T_fb940_row3_col5" class="data row3 col5" >2.283105</td>
#       <td id="T_fb940_row3_col6" class="data row3 col6" >63.803684</td>
#     </tr>
#     <tr>
#       <th id="T_fb940_level0_row4" class="row_heading level0 row4" >40-44_M</th>
#       <td id="T_fb940_row4_col0" class="data row4 col0" >16208132</td>
#       <td id="T_fb940_row4_col1" class="data row4 col1" >2559</td>
#       <td id="T_fb940_row4_col2" class="data row4 col2" >4193.149997</td>
#       <td id="T_fb940_row4_col3" class="data row4 col3" >77</td>
#       <td id="T_fb940_row4_col4" class="data row4 col4" >0.015788</td>
#       <td id="T_fb940_row4_col5" class="data row4 col5" >3.008988</td>
#       <td id="T_fb940_row4_col6" class="data row4 col6" >54.456493</td>
#     </tr>
#     <tr>
#       <th id="T_fb940_level0_row5" class="row_heading level0 row5" >35-39_M</th>
#       <td id="T_fb940_row5_col0" class="data row5 col0" >20665139</td>
#       <td id="T_fb940_row5_col1" class="data row5 col1" >2933</td>
#       <td id="T_fb940_row5_col2" class="data row5 col2" >5051.080003</td>
#       <td id="T_fb940_row5_col3" class="data row5 col3" >112</td>
#       <td id="T_fb940_row5_col4" class="data row5 col4" >0.014193</td>
#       <td id="T_fb940_row5_col5" class="data row5 col5" >3.818616</td>
#       <td id="T_fb940_row5_col6" class="data row5 col6" >45.098929</td>
#     </tr>
#     <tr>
#       <th id="T_fb940_level0_row6" class="row_heading level0 row6" >30-34_F</th>
#       <td id="T_fb940_row6_col0" class="data row6 col0" >31571576</td>
#       <td id="T_fb940_row6_col1" class="data row6 col1" >5099</td>
#       <td id="T_fb940_row6_col2" class="data row6 col2" >7611.479995</td>
#       <td id="T_

# %% [markdown]
# **3) Which ad creatives or campaign types generate the greatest engagement (CTR) and conversions?**

# %%
d3 = kag.groupby("ad_id")[["Impressions","Clicks" ,"Spent","Approved_Conversion"]].sum().reset_index()
d3
# Out:
#         ad_id  Impressions  Clicks       Spent  Approved_Conversion
# 0      708746         7350       1    1.430000                    1
# 1      708749        17861       2    1.820000                    0
# 2      708771          693       0    0.000000                    0
# 3      708815         4259       1    1.250000                    0
# 4      708818         4133       1    1.290000                    1
# ...       ...          ...     ...         ...                  ...
# 1138  1314410      1129773     252  358.189997                    2
# 1139  1314411       637549     120  173.880003                    0
# 1140  1314412       151531      28   40.289999                    0
# 1141  1314414       790253     135  198.710001                    2
# 1142  1314415       513161     114  165.609999                    2
#
# [1143 rows x 5 columns]

# %%
d3["CTR"] = (d3["Clicks"] / d3["Impressions"])*100
d3["Conversion_Rate"] = np.where(d3["Clicks"] > 0, (d3["Approved_Conversion"] / d3["Clicks"])*100, 0)
d3["CPA"] = np.where(d3["Approved_Conversion"] > 0, d3["Spent"] / d3["Approved_Conversion"], 0)
d3 = d3.set_index("ad_id").sort_values(by="CTR", ascending=False)
d3
# Out:
#         Impressions  Clicks  Spent  Approved_Conversion       CTR  \
# ad_id
# 738637          944       1   1.42                    0  0.105932
# 950224         2367       2   2.84                    1  0.084495
# 951779         3277       2   2.68                    0  0.061031
# 951202         5307       3   4.29                    1  0.056529
# 950537         1884       1   1.41                    0  0.053079
# ...             ...     ...    ...                  ...       ...
# 734313          790       0   0.00                    1  0.000000
# 734314          962       0   0.00                    0  0.000000
# 708771          693       0   0.00                    0  0.000000
# 708979         1224       0   0.00                    0  0.000000
# 708820         1915       0   0.00                    1  0.000000
#
#         Conversion_Rate   CPA
# ad_id
# 738637         0.000000  0.00
# 950224        50.000000  2.84
# 951779         0.000000  0.00
# 951202        33.333333  4.29
# 950537         0.000000  0.00
# ...                 ...   ...
# 734313         0.000000  0.00
# 734314         0.000000  0.00
# 708771         0.000000  0.00
# 708979         0.000000  0.00
# 708820         0.000000  0.00
#
# [1143 rows x 7 columns]

# %%
print(d3["CTR"].idxmax())
# Out:
# 738637

# %%
d3 = d3.reset_index().head(100)
d3["ad_id"] = d3["ad_id"].astype(str)
plt.figure(figsize=(20,4))
sns.lineplot(data = d3, x="ad_id", y="CTR")
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(20,4))
sns.lineplot(data = d3, x="ad_id", y="Conversion_Rate", color ="green")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **4) What are the time-based performance trends - are there optimal days or times for ad spend?**

# %%
# As Date and Time information is not given, so we assume "xyz_campaign_id", "fb_campaign_id"  as proxies for performance trends.

d4 = kag.groupby(["xyz_campaign_id", "fb_campaign_id"])[["Impressions","Clicks" ,"Spent","Approved_Conversion"]].sum().reset_index()
d4
# Out:
#      xyz_campaign_id  fb_campaign_id  Impressions  Clicks       Spent  \
# 0                916          103916         7350       1    1.430000
# 1                916          103917        17861       2    1.820000
# 2                916          103920          693       0    0.000000
# 3                916          103928         8392       2    2.540000
# 4                916          103929         1915       0    0.000000
# ..               ...             ...          ...     ...         ...
# 686             1178          179977      1129773     252  358.189997
# 687             1178          179978       637549     120  173.880003
# 688             1178          179979       151531      28   40.289999
# 689             1178          179981       790253     135  198.710001
# 690             1178          179982       513161     114  165.609999
#
#      Approved_Conversion
# 0                      1
# 1                      0
# 2                      0
# 3                      1
# 4                      1
# ..                   ...
# 686                    2
# 687                    0
# 688                    0
# 689                    2
# 690                    2
#
# [691 rows x 6 columns]

# %%
d4["CTR"] = (d4["Clicks"] / d4["Impressions"])*100
d4["Conversion_Rate"] = np.where(d4["Clicks"] > 0, (d4["Approved_Conversion"] / d4["Clicks"])*100, 0)
d4["CPA"] = np.where(d4["Approved_Conversion"] > 0, d4["Spent"] / d4["Approved_Conversion"], 0)
d4 = d4.set_index("xyz_campaign_id")
d4
# Out:
#                  fb_campaign_id  Impressions  Clicks       Spent  \
# xyz_campaign_id
# 916                      103916         7350       1    1.430000
# 916                      103917        17861       2    1.820000
# 916                      103920          693       0    0.000000
# 916                      103928         8392       2    2.540000
# 916                      103929         1915       0    0.000000
# ...                         ...          ...     ...         ...
# 1178                     179977      1129773     252  358.189997
# 1178                     179978       637549     120  173.880003
# 1178                     179979       151531      28   40.289999
# 1178                     179981       790253     135  198.710001
# 1178                     179982       513161     114  165.609999
#
#                  Approved_Conversion       CTR  Conversion_Rate         CPA
# xyz_campaign_id
# 916                                1  0.013605       100.000000    1.430000
# 916                                0  0.011198         0.000000    0.000000
# 916                                0  0.000000         0.000000    0.000000
# 916                                1  0.023832        50.000000    2.540000
# 916                                1  0.000000         0.000000    0.000000
# ...                              ...       ...              ...         ...
# 1178                               2  0.022305         0.793651  179.094999
# 1178                               0  0.018822         0.000000    0.000000
# 1178                               0  0.018478         0.000000    0.000000
# 1178                               2  0.017083         1.481481   99.355000
# 1178                               2  0.022215         1.754386   82.804999
#
# [691 rows x 8 columns]

# %%
d4 = d4.reset_index()
d4["fb_campaign_id"] = d4["fb_campaign_id"].astype(str)
plt.figure(figsize=(22,6))
sns.lineplot(data=d4, x="fb_campaign_id", y="CPA", hue="xyz_campaign_id", palette = "tab10")
plt.xticks(ticks=d4["fb_campaign_id"], rotation=90)
plt.title("CPA Trends across Facebook Campaigns")
plt.xlabel("Facebook Campaign ID")
plt.ylabel("CPA")
plt.show()

# %% [markdown]
# **5) 	How should future budgets be reallocated to maximize ROI across channels and segments?**

# %%
# We assumed each approved conversion generates a fixed revenue of 100 units. This assumption allows us to calculate ROI in a standardized way.

d5a = kag.groupby(["Age_Gender"]).agg({"Spent" : "sum","Approved_Conversion" : "sum" }).reset_index()

d5a["CPA"] = np.where(d5a["Approved_Conversion"] > 0, d5a["Spent"] / d5a["Approved_Conversion"], 0)
d5a["CPS"] = np.where(d5a["Spent"] > 0, d5a["Approved_Conversion"]/d5a["Spent"], 0)
d5a["ROI"] = np.where(d5a["Spent"] > 0,(d5a["Approved_Conversion"]*100 - d5a["Spent"]) / d5a["Spent"],0)
d5a["ROI_Positive"] = d5a["ROI"].clip(lower=0)

Total_spend = d5a["Spent"].sum()

d5a["Recommended_Budget"] = (d5a["ROI_Positive"] / d5a["ROI_Positive"].sum()) * Total_spend
d5a["Recommended_Budget"] = d5a.apply(lambda row: min(row["Recommended_Budget"], row["Spent"]*2), axis=1) # Here is maximum budget spent limit set 2 times.
d5a["Exp_CPA"] = np.where(d5a["Approved_Conversion"] > 0, d5a["Recommended_Budget"] / d5a["Approved_Conversion"], 0)
d5a["Exp_ROI"] = np.where(d5a["Recommended_Budget"] > 0,(d5a["Approved_Conversion"]*100 - d5a["Recommended_Budget"]) / d5a["Recommended_Budget"],0)
heatmap1 = d5a.style.background_gradient(cmap="YlGnBu")
heatmap1
# Out:
# <style type="text/css">
# #T_edbee_row0_col1 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_edbee_row0_col2 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_edbee_row0_col3 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_edbee_row0_col4, #T_edbee_row0_col5 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_edbee_row0_col6, #T_edbee_row7_col3 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_edbee_row0_col7 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_edbee_row0_col8 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_edbee_row0_col9 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_edbee_row1_col1 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_edbee_row1_col2, #T_edbee_row1_col4, #T_edbee_row1_col5, #T_edbee_row1_col6, #T_edbee_row1_col7, #T_edbee_row3_col8, #T_edbee_row4_col9, #T_edbee_row5_col8, #T_edbee_row6_col1, #T_edbee_row6_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_edbee_row1_col3, #T_edbee_row5_col1, #T_edbee_row5_col2, #T_edbee_row6_col4, #T_edbee_row6_col5, #T_edbee_row6_col6, #T_edbee_row6_col7, #T_edbee_row6_col8, #T_edbee_row6_col9 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_edbee_row1_col8 {
#   background-color: #2094c0;
#   color: #f1f1f1;
# }
# #T_edbee_row1_col9, #T_edbee_row4_col8 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_edbee_row2_col1 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_edbee_row2_col2 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_edbee_row2_col3 {
#   background-color: #71c8bd;
#   color: #000000;
# }
# #T_edbee_row2_col4, #T_edbee_row2_col5 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_edbee_row2_col6 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_edbee_row2_col7 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_edbee_row2_col8 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_edbee_row2_col9 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_edbee_row3_col1 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_edbee_row3_col2, #T_edbee_row6_col2, #T_edbee_row7_col7 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_edbee_row3_col3 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_edbee_row3_col4, #T_edbee_row3_col5 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_edbee_row3_col6 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_edbee_row3_col7 {
#   background-color: #2195c0;
#   color: #f1f1f1;
# }
# #T_edbee_row3_col9, #T_edbee_row5_col9 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_edbee_row4_col1 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_edbee_row4_col2 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_edbee_row4_col3 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_edbee_row4_col4, #T_edbee_row4_col5 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_edbee_row4_col6 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_edbee_row4_col7 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_edbee_row5_col3 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_edbee_row5_col4, #T_edbee_row5_col5 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_edbee_row5_col6 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_edbee_row5_col7 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_edbee_row7_col1 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_edbee_row7_col2 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_edbee_row7_col4, #T_edbee_row7_col5 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_edbee_row7_col6 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_edbee_row7_col8 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_edbee_row7_col9 {
#   background-color: #23499e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_edbee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edbee_level0_col0" class="col_heading level0 col0" >Age_Gender</th>
#       <th id="T_edbee_level0_col1" class="col_heading level0 col1" >Spent</th>
#       <th id="T_edbee_level0_col2" class="col_heading level0 col2" >Approved_Conversion</th>
#       <th id="T_edbee_level0_col3" class="col_heading level0 col3" >CPA</th>
#       <th id="T_edbee_level0_col4" class="col_heading level0 col4" >CPS</th>
#       <th id="T_edbee_level0_col5" class="col_heading level0 col5" >ROI</th>
#       <th id="T_edbee_level0_col6" class="col_heading level0 col6" >ROI_Positive</th>
#       <th id="T_edbee_level0_col7" class="col_heading level0 col7" >Recommended_Budget</th>
#       <th id="T_edbee_level0_col8" class="col_heading level0 col8" >Exp_CPA</th>
#       <th id="T_edbee_level0_col9" class="col_heading level0 col9" >Exp_ROI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edbee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edbee_row0_col0" class="data row0 col0" >30-34_F</td>
#       <td id="T_edbee_row0_col1" class="data row0 col1" >7611.479995</td>
#       <td id="T_edbee_row0_col2" class="data row0 col2" >195</td>
#       <td id="T_edbee_row0_col3" class="data row0 col3" >39.033231</td>
#       <td id="T_edbee_row0_col4" class="data row0 col4" >0.025619</td>
#       <td id="T_edbee_row0_col5" class="data row0 col5" >1.561920</td>
#       <td id="T_edbee_row0_col6" class="data row0 col6" >1.561920</td>
#       <td id="T_edbee_row0_col7" class="data row0 col7" >11962.049214</td>
#       <td id="T_edbee_row0_col8" class="data row0 col8" >61.343842</td>
#       <td id="T_edbee_row0_col9" class="data row0 col9" >0.630155</td>
#     </tr>
#     <tr>
#       <th id="T_edbee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edbee_row1_col0" class="data row1 col0" >30-34_M</td>
#       <td id="T_edbee_row1_col1" class="data row1 col1" >7640.919991</td>
#       <td id="T_edbee_row1_col2" class="data row1 col2" >299</td>
#       <td id="T_edbee_row1_col3" class="data row1 col3" >25.554916</td>
#       <td id="T_edbee_row1_col4" class="data row1 col4" >0.039131</td>
#       <td id="T_edbee_row1_col5" class="data row1 col5" >2.913141</td>
#       <td id="T_edbee_row1_col6" class="data row1 col6" >2.913141</td>
#       <td id="T_edbee_row1_col7" class="data row1 col7" >15281.839983</td>
#       <td id="T_edbee_row1_col8" class="data row1 col8" >51.109833</td>
#       <td id="T_edbee_row1_col9" class="data row1 col9" >0.956571</td>
#     </tr>
#     <tr>
#       <th id="T_edbee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edbee_row2_col0" class="data row2 col0" >35-39_F</td>
#       <td id="T_edbee_row2_col1" class="data row2 col1" >6061.349992</td>
#       <td id="T_edbee_row2_col2" class="data row2 col2" >95</td>
#       <td id="T_edbee_row2_col3" class="data row2 col3" >63.803684</td>
#       <td id="T_edbee_row2_col4" class="data row2 col4" >0.015673</td>
#       <td id="T_edbee_row2_col5" class="data row2 col5" >0.567308</td>
#       <td id="T_edbee_row2_col6" class="data row2 col6" >0.567308</td>
#       <td id="T_edbee_row2_col7" class="data row2 col7" >4344.757239</td>
#       <td id="T_edbee_row2_col8" class="data row2 col8" >45.734287</td>
#       <td id="T_edbee_row2_col9" class="data row2 col9" >1.186543</td>
#     </tr>
#     <tr>
#       <th id="T_edbee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edbee_row3_col0" class="data row3 col0" >35-39_M</td>
#       <td id="T_edbee_row3_col1" class="data row3 col1" >5051.080003</td>
#       <td id="T_edbee_row3_col2" class="data row3 col2" >112</td>
#       <td id="T_edbee_row3_col3" class="data row3 col3" >45.098929</td>
#       <td id="T_edbee_row3_col4" class="data row3 col4" >0.022173</td>
#       <td id="T_edbee_row3_col5" class="data row3 col5" >1.217348</td>
#       <td id="T_edbee_row3_col6" class="data row3 col6" >1.217348</td>
#       <td id="T_edbee_row3_col7" class="data row3 col7" >9323.124795</td>
#       <td id="T_edbee_row3_col8" class="data row3 col8" >83.242186</td>
#       <td id="T_edbee_row3_col9" class="data row3 col9" >0.201314</td>
#     </tr>
#     <tr>
#       <th id="T_edbee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edbee_row4_col0" class="data row4 col0" >4

# %%
d5a.set_index("Age_Gender")[["Spent", "Recommended_Budget"]].plot(kind="bar", figsize=(10,6))
plt.title("Comparision of Spend vs Recommended Budget by Age and Gender")
plt.ylabel("Amount")
plt.xlabel("Age and Gender")
plt.xticks(rotation = 0)
plt.show()

# %%
d5a.set_index("Age_Gender")[["CPA", "Exp_CPA"]].plot(kind="bar", figsize=(10,6))
plt.title("Comparision of CPA vs Exp_CPA by Age and Gender")
plt.ylabel("Value")
plt.xlabel("Age and Gender")
plt.xticks(rotation = 0)
plt.show()

# %%
d5a.set_index("Age_Gender")[["ROI", "Exp_ROI"]].plot(kind="bar", figsize=(10,6))
plt.title("Comparision of ROI vs Exp_ROI by Age and Gender")
plt.ylabel("Value")
plt.xlabel("Age and Gender")
plt.xticks(rotation = 0)
plt.show()

# %%
d5b = kag.groupby(["xyz_campaign_id"]).agg({"Spent" : "sum","Approved_Conversion" : "sum"}).reset_index()

d5b["CPA"] = np.where(d5b["Approved_Conversion"] > 0, d5b["Spent"] / d5b["Approved_Conversion"], 0)
d5b["CPS"] = np.where(d5b["Spent"] > 0, d5b["Approved_Conversion"]/d5b["Spent"], 0)
d5b["ROI"] = np.where(d5b["Spent"] > 0,(d5b["Approved_Conversion"]*100 - d5b["Spent"]) / d5b["Spent"],0)
d5b["ROI_Positive"] = d5b["ROI"].clip(lower=0)

Total_spend = d5b["Spent"].sum()

d5b["Recommended_Budget"] = (d5b["ROI_Positive"] / d5b["ROI_Positive"].sum()) * Total_spend
d5b["Recommended_Budget"] = d5b.apply(lambda row: min(row["Recommended_Budget"], row["Spent"]*2), axis=1)  # Here is maximum budget spent limit set 2 times.
d5b["Exp_CPA"] = np.where(d5b["Approved_Conversion"] > 0, d5b["Recommended_Budget"] / d5b["Approved_Conversion"], 0)
d5b["Exp_ROI"] = np.where(d5b["Recommended_Budget"] > 0,(d5b["Approved_Conversion"]*100 - d5b["Recommended_Budget"]) / d5b["Recommended_Budget"],0)
heatmap2 = d5b.style.background_gradient(cmap="YlGnBu")
heatmap2
# Out:
# <style type="text/css">
# #T_bf91d_row0_col0, #T_bf91d_row0_col1, #T_bf91d_row0_col2, #T_bf91d_row0_col3, #T_bf91d_row0_col7, #T_bf91d_row1_col9, #T_bf91d_row2_col4, #T_bf91d_row2_col5, #T_bf91d_row2_col6, #T_bf91d_row2_col8 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_bf91d_row0_col4, #T_bf91d_row0_col5, #T_bf91d_row0_col6, #T_bf91d_row1_col7, #T_bf91d_row1_col8, #T_bf91d_row2_col0, #T_bf91d_row2_col1, #T_bf91d_row2_col2, #T_bf91d_row2_col3, #T_bf91d_row2_col9 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_bf91d_row0_col8 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_bf91d_row0_col9 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_bf91d_row1_col0 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_bf91d_row1_col1 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_bf91d_row1_col2 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_bf91d_row1_col3 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_bf91d_row1_col4, #T_bf91d_row1_col5, #T_bf91d_row1_col6 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_bf91d_row2_col7 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# </style>
# <table id="T_bf91d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf91d_level0_col0" class="col_heading level0 col0" >xyz_campaign_id</th>
#       <th id="T_bf91d_level0_col1" class="col_heading level0 col1" >Spent</th>
#       <th id="T_bf91d_level0_col2" class="col_heading level0 col2" >Approved_Conversion</th>
#       <th id="T_bf91d_level0_col3" class="col_heading level0 col3" >CPA</th>
#       <th id="T_bf91d_level0_col4" class="col_heading level0 col4" >CPS</th>
#       <th id="T_bf91d_level0_col5" class="col_heading level0 col5" >ROI</th>
#       <th id="T_bf91d_level0_col6" class="col_heading level0 col6" >ROI_Positive</th>
#       <th id="T_bf91d_level0_col7" class="col_heading level0 col7" >Recommended_Budget</th>
#       <th id="T_bf91d_level0_col8" class="col_heading level0 col8" >Exp_CPA</th>
#       <th id="T_bf91d_level0_col9" class="col_heading level0 col9" >Exp_ROI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf91d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf91d_row0_col0" class="data row0 col0" >916</td>
#       <td id="T_bf91d_row0_col1" class="data row0 col1" >149.710001</td>
#       <td id="T_bf91d_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_bf91d_row0_col3" class="data row0 col3" >6.237917</td>
#       <td id="T_bf91d_row0_col4" class="data row0 col4" >0.160310</td>
#       <td id="T_bf91d_row0_col5" class="data row0 col5" >15.030993</td>
#       <td id="T_bf91d_row0_col6" class="data row0 col6" >15.030993</td>
#       <td id="T_bf91d_row0_col7" class="data row0 col7" >299.420001</td>
#       <td id="T_bf91d_row0_col8" class="data row0 col8" >12.475833</td>
#       <td id="T_bf91d_row0_col9" class="data row0 col9" >7.015497</td>
#     </tr>
#     <tr>
#       <th id="T_bf91d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf91d_row1_col0" class="data row1 col0" >936</td>
#       <td id="T_bf91d_row1_col1" class="data row1 col1" >2893.369999</td>
#       <td id="T_bf91d_row1_col2" class="data row1 col2" >183</td>
#       <td id="T_bf91d_row1_col3" class="data row1 col3" >15.810765</td>
#       <td id="T_bf91d_row1_col4" class="data row1 col4" >0.063248</td>
#       <td id="T_bf91d_row1_col5" class="data row1 col5" >5.324805</td>
#       <td id="T_bf91d_row1_col6" class="data row1 col6" >5.324805</td>
#       <td id="T_bf91d_row1_col7" class="data row1 col7" >5786.739998</td>
#       <td id="T_bf91d_row1_col8" class="data row1 col8" >31.621530</td>
#       <td id="T_bf91d_row1_col9" class="data row1 col9" >2.162402</td>
#     </tr>
#     <tr>
#       <th id="T_bf91d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf91d_row2_col0" class="data row2 col0" >1178</td>
#       <td id="T_bf91d_row2_col1" class="data row2 col1" >55662.149959</td>
#       <td id="T_bf91d_row2_col2" class="data row2 col2" >872</td>
#       <td id="T_bf91d_row2_col3" class="data row2 col3" >63.832741</td>
#       <td id="T_bf91d_row2_col4" class="data row2 col4" >0.015666</td>
#       <td id="T_bf91d_row2_col5" class="data row2 col5" >0.566594</td>
#       <td id="T_bf91d_row2_col6" class="data row2 col6" >0.566594</td>
#       <td id="T_bf91d_row2_col7" class="data row2 col7" >1589.781964</td>
#       <td id="T_bf91d_row2_col8" class="data row2 col8" >1.823144</td>
#       <td id="T_bf91d_row2_col9" class="data row2 col9" >53.850289</td>
#     </tr>
#   </tbody>
# </table>

# %%
d5b.set_index("xyz_campaign_id")[["Spent", "Recommended_Budget"]].plot(kind="bar", figsize=(10,6))
plt.title("Spend vs Recommended Budget by XYZ Campaign ID")
plt.ylabel("Amount")
plt.xlabel("XYZ Campaign ID")
plt.xticks(rotation = 0)
plt.show()

# %%
d5b.set_index("xyz_campaign_id")[["CPA","Exp_CPA","ROI","Exp_ROI"]].plot(kind="bar", figsize=(10,6))
plt.title("Spend vs Recommended Budget by XYZ Campaign ID")
plt.ylabel("Amount")
plt.xlabel("XYZ Campaign ID")
plt.xticks(rotation = 0)
plt.show()

# %%
d5c = kag.groupby(["interest"]).agg({"Spent" : "sum","Approved_Conversion" : "sum" }).reset_index()

d5c["CPA"] = np.where(d5c["Approved_Conversion"] > 0, d5c["Spent"] / d5c["Approved_Conversion"], 0)
d5c["CPS"] = np.where(d5c["Spent"] > 0, d5c["Approved_Conversion"]/d5c["Spent"], 0)
d5c["ROI"] = np.where(d5c["Spent"] > 0,(d5c["Approved_Conversion"]*100 - d5c["Spent"]) / d5c["Spent"],0)
d5c["ROI_Positive"] = d5c["ROI"].clip(lower=0)

Total_spend = d5c["Spent"].sum()

d5c["Recommended_Budget"] = (d5c["ROI_Positive"] / d5c["ROI_Positive"].sum()) * Total_spend
d5c["Recommended_Budget"] = d5c.apply(lambda row: min(row["Recommended_Budget"], row["Spent"]*1.5), axis=1) # Here is maximum budget spent limit set 1.5 times.
d5c["Exp_CPA"] = np.where(d5c["Approved_Conversion"] > 0, d5c["Recommended_Budget"] / d5c["Approved_Conversion"], 0)
d5c["Exp_ROI"] = np.where(d5c["Recommended_Budget"] > 0,(d5c["Approved_Conversion"]*100 - d5c["Recommended_Budget"]) / d5c["Recommended_Budget"],0)
heatmap3 = d5c.style.background_gradient(cmap="YlGnBu")
heatmap3
# Out:
# <style type="text/css">
# #T_74809_row0_col0, #T_74809_row17_col9, #T_74809_row18_col3, #T_74809_row20_col1, #T_74809_row24_col1, #T_74809_row24_col2, #T_74809_row24_col9, #T_74809_row25_col9, #T_74809_row27_col1, #T_74809_row30_col4, #T_74809_row30_col5, #T_74809_row30_col6, #T_74809_row30_col7, #T_74809_row30_col8, #T_74809_row30_col9, #T_74809_row34_col6, #T_74809_row34_col7, #T_74809_row34_col8, #T_74809_row34_col9, #T_74809_row35_col9, #T_74809_row39_col2, #T_74809_row39_col9 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_74809_row0_col1, #T_74809_row9_col6, #T_74809_row25_col2, #T_74809_row35_col2, #T_74809_row37_col1 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_74809_row0_col2, #T_74809_row1_col2, #T_74809_row12_col2, #T_74809_row23_col2, #T_74809_row23_col3, #T_74809_row39_col4, #T_74809_row39_col5 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_74809_row0_col3, #T_74809_row15_col4, #T_74809_row15_col5, #T_74809_row18_col2 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_74809_row0_col4, #T_74809_row0_col5 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_74809_row0_col6 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_74809_row0_col7 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# #T_74809_row0_col8, #T_74809_row22_col8 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_74809_row0_col9, #T_74809_row7_col9, #T_74809_row22_col9, #T_74809_row33_col9, #T_74809_row38_col1 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_74809_row1_col0, #T_74809_row20_col2, #T_74809_row25_col1, #T_74809_row33_col6, #T_74809_row36_col2 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_74809_row1_col1, #T_74809_row9_col2, #T_74809_row10_col4, #T_74809_row10_col5, #T_74809_row12_col4, #T_74809_row12_col5, #T_74809_row16_col9, #T_74809_row17_col2, #T_74809_row30_col1 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_74809_row1_col3, #T_74809_row6_col4, #T_74809_row6_col5 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_74809_row1_col4, #T_74809_row1_col5, #T_74809_row6_col3 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_74809_row1_col6 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_74809_row1_col7, #T_74809_row37_col8 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_74809_row1_col8, #T_74809_row37_col6 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_74809_row1_col9, #T_74809_row14_col6, #T_74809_row14_col8, #T_74809_row28_col6, #T_74809_row31_col6, #T_74809_row36_col9, #T_74809_row39_col1 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_74809_row2_col0, #T_74809_row12_col9, #T_74809_row15_col6 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_74809_row2_col1 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_74809_row2_col2 {
#   background-color: #1d8dbe;
#   color: #f1f1f1;
# }
# #T_74809_row2_col3 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_74809_row2_col4, #T_74809_row2_col5, #T_74809_row15_col7, #T_74809_row19_col4, #T_74809_row19_col5 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_74809_row2_col6, #T_74809_row24_col4, #T_74809_row24_col5, #T_74809_row35_col4, #T_74809_row35_col5 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_74809_row2_col7 {
#   background-color: #48b9c3;
#   color: #f1f1f1;
# }
# #T_74809_row2_col8, #T_74809_row9_col1, #T_74809_row10_col7, #T_74809_row28_col8 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_74809_row2_col9, #T_74809_row5_col6, #T_74809_row21_col6, #T_74809_row28_col9 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_74809_row3_col0, #T_74809_row12_col7, #T_74809_row32_col2 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_74809_row3_col1, #T_74809_row20_col0 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_74809_row3_col2, #T_74809_row4_col3, #T_74809_row6_col7, #T_74809_row8_col8 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_74809_row3_col3, #T_74809_row17_col0, #T_74809_row38_col4, #T_74809_row38_col5 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_74809_row3_col4, #T_74809_row3_col5, #T_74809_row38_col3 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_74809_row3_col6 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_74809_row3_col7 {
#   background-color: #233390;
#   color: #f1f1f1;
# }
# #T_74809_row3_col8, #T_74809_row5_col1, #T_74809_row11_col6 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_74809_row3_col9, #T_74809_row14_col4, #T_74809_row14_col5, #T_74809_row14_col7, #T_74809_row19_col9, #T_74809_row20_col9, #T_74809_row28_col4, #T_74809_row28_col5, #T_74809_row28_col7, #T_74809_row31_col4, #T_74809_row31_col5 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_74809_row4_col0 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_74809_row4_col1, #T_74809_row4_col2, #T_74809_row14_col9, #T_74809_row16_col7, #T_74809_row18_col4, #T_74809_row18_col5, #T_74809_row18_col6, #T_74809_row30_col3, #T_74809_row39_col0, #T_74809_row39_col8 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_74809_row4_col4, #T_74809_row4_col5 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_74809_row4_col6, #T_74809_row8_col0, #T_74809_row24_col6 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_74809_row4_col7 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_74809_row4_col8, #T_74809_row5_col9, #T_74809_row21_col9 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_74809_row4_col9, #T_74809_row5_col0 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_74809_row5_col2, #T_74809_row6_col2, #T_74809_row13_col0 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_74809_row5_col3, #T_74809_row16_col1 {
#   background-color: #2094c0;
#   color: #f1f1f1;
# }
# #T_74809_row5_col4, #T_74809_row5_col5, #T_74809_row15_col9, #T_74809_row21_col4, #T_74809_row21_col5, #T_74809_row31_col9 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_74809_row5_col7, #T_74809_row7_col1, #T_74809_row14_col0, #T_74809_row19_col1, #T_74809_row19_col2 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_74809_row5_col8, #T_74809_row21_col8, #T_74809_row27_col3 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_74809_row6_col0, #T_74809_row16_col8, #T_74809_row27_col7, #T_74809_row37_col3 {
#   background-color: #e6f5b2;
#   color: #000000;
# }
# #T_74809_row6_col1, #T_74809_row21_col2 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_74809_row6_col6, #T_74809_row7_col0, #T_74809_row22_col1, #T_74809_row24_col7 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_74809_row6_col8, #T_74809_row18_col8 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_74809_row6_col9, #T_74809_row18_col9, #T_74809_row29_col2, #T_74809_row34_col2 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_74809_row7_col2 {
#   background-color: #a2dbb8;
#   color: #000000;
# }
# #T_74809_row7_col3, #T_74809_row18_col0, #T_74809_row36_col7 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_74809_row7_col4, #T_74809_row7_col5, #T_74809_row29_col3 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_74809_row7_col6 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# #T_74809_row7_col7, #T_74809_row14_col3, #T_74809_row28_col3 {
#   background-color: #253795;
#   color: #f1f1f1;
# }
# #T_74809_row7_col8 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_74809_row8_col1, #T_74809_row11_col2, #T_74809_row37_col2 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_74809_row8_col2, #T_74809_row22_col2, #T_74809_row35_col6 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_74809_row8_col3, #T_74809_row25_col6, #T_74809_row26_col3 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_74809_row8_col4, #T_74809_row8_col5, #T_74809_row26_col6 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_74809_row8_col6 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_74809_row8_col7 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_74809_row8_col9, #T_74809_row18_col1, #T_74809_row23_col9, #T_74809_row26_col9, #T_74809_row27_col9, #T_74809_row30_col2, #T_74809_row34_col4, #T_74809_row34_col5, #T_74809_row37_col9 {
#   background-color: #fdfed5;
#   color:

# %%
d5c.set_index("interest")[["Spent", "Recommended_Budget"]].plot(kind="bar", figsize=(20,6))
plt.title("Spend vs Recommended Budget by Interest")
plt.ylabel("Amount")
plt.xlabel("Interest")
plt.xticks(rotation = 0)
plt.show()

# %%
d5c.set_index("interest")[["CPA","Exp_CPA","ROI","Exp_ROI"]].plot(kind="bar", figsize=(22,6))
plt.title("Spend vs Recommended Budget by XYZ Campaign ID")
plt.ylabel("Amount")
plt.xlabel("Audience Interest")
plt.xticks(rotation = 0)
plt.show()
